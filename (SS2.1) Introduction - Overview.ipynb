# %% [markdown]
# # Technical Analysis
#
# This module will be the introduction into some basic technical analysis modelling.
# <br>
# We will look at:
# $\bullet$ Simple and Exponential Moving Average
# $\bullet$ On-Balance Volume
# $\bullet$ Relative Strength Index
# $\bullet$ Money Fund Index
# $\bullet$ Stochastic Oscillator
#
# We can stretch this and look at the Ichimoku (Ichimoku Kinko Hyo) Cloud - but it's a bit too complicated for my liking because I still believe technical analysis is rather useless, so I don't think we should bother with stretching our modelling too far into this matter - technical analyis.
#
# On top of just modelling the trading graphs and plots, we will also add in the buy and sell indicators to tell us when to buy and sell into the assets.
#
# For the sake of simplicity, we shall be using a single asset here to trade.
# <br>
# We can extend this to multiple assets easily, but we're lazy and if we wanted to it would just simply be some for loops.
#
# A brief overview of what all this will look like is shown below:

# %%
import TechnicalAnalysis1 as ta1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as pdr

plt.style.use('dark_background')

# %%
asset = pdr.DataReader('JPM', 'yahoo', start='2018-01-01', end='2021-12-01')
close = asset['Adj Close']
volume = asset['Volume']

# %%
sma_dataframe = ta1.sma(close)

# %%
obv_dataframe = ta1.obv(close, volume)
